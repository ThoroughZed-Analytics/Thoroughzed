# %%
## pip install hvplot
## pip install jupyterlab
## OUTSIDE OF VENV - pip3 install panel

import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %%
df = pd.read_csv("data/master_data/all_horse_meta_oliver.csv")
df
# Out:
#       Unnamed: 0 data.horse.bloodline data.horse.breed_type  \
# 0              0              Buterin               genesis
# 1              0              Buterin               genesis
# 2              0              Buterin                 pacer
# 3              0              Buterin                 pacer
# 4              0              Buterin                 pacer
# ...          ...                  ...                   ...
# 2223           0              Buterin             legendary
# 2224           0             Nakamoto             exclusive
# 2225           0              Buterin             exclusive
# 2226           0               Finney             exclusive
# 2227           0               Finney             exclusive
#
#          data.horse.color data.horse.gen data.horse.horse_type  \
# 0        Anti-Flash White             Z9                  Mare
# 1          Shadow Fighter             Z9                  Mare
# ...
